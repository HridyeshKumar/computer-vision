# %% [markdown]
# Building a Cropping Tool

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
img = cv2.imread('2211.w018.n002.1449B.p15.1449.jpg')
print(f"Image loaded successfully with shape: {img.shape}")
# Out:
# Image loaded successfully with shape: (3900, 5318, 3)

# %%
flag=False
ix=-1
iy=-1

def crop(event,x,y,flags,params):
  if event==1:
    flag=True
    ix=x
    iy=y
  elif event==0:
      if flag==True:
          cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
  elif event==4:
      flag=False
      cv2.rectangle(img,pt1=(ix,iy),pt2=(x,y),color=(0,255,255),thickness=-1)
cv2.namedWindow(winname="window")
cv2.setMouseCallback("window",crop)
while True:
  cv2_imshow(img)
  if cv2.waitKey(1) & 0xFF == ord('x'):
    break
cv2.destroyAllWindows()
